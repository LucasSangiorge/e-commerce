# %%
import db_connection
conn = db_connection.get_connection()
print("Conexão OK")
# Out:
# Conexão OK

# %%
import pandas as pd
import db_connection

conn = db_connection.get_connection()

df_faturamento = pd.read_sql(
    "SELECT * FROM vw_faturamento_mensal_gold",
    conn
)
df_faturamento.head(10)
# Out:
# C:\Users\lucas\AppData\Local\Temp\ipykernel_27688\3152389031.py:6: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_faturamento = pd.read_sql(
#        mes  faturamento
# 0  2024-07     522060.0
# 1  2024-02     520170.0
# 2  2023-03     524580.0
# 3  2023-04     676280.0
# 4  2024-01     381850.0
# 5  2024-10     551080.0
# 6  2024-08     436260.0
# 7  2023-08     537210.0
# 8  2023-07     433010.0
# 9  2023-11     514330.0
